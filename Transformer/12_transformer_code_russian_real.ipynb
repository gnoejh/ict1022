# %% [markdown]
# <a href="https://colab.research.google.com/github/gnoejh/ict1022/blob/main/Transformer/12_transformer_code_russian_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import math

# %% [markdown]
# # Transformer

# %% [markdown]
# ### 1. Using nn.Transformer for the Full Model

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, embed_size, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, embed_size)
        for pos in range(max_len):
            for i in range(0, embed_size, 2):
                pe[pos, i] = math.sin(pos / (10000 ** ((2 * i) / embed_size)))
                pe[pos, i + 1] = math.cos(pos / (10000 ** ((2 * i) / embed_size)))
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return x

class TransformerConfig:
    """Configuration class to store all transformer related parameters"""
    def __init__(self, **kwargs):
        self.src_vocab_size = kwargs.get('src_vocab_size', 15)
        self.tgt_vocab_size = kwargs.get('tgt_vocab_size', 15)
        self.embed_size = kwargs.get('embed_size', 16)
        self.num_heads = kwargs.get('num_heads', 4)
        self.num_layers = kwargs.get('num_layers', 3)
        self.forward_expansion = kwargs.get('forward_expansion', 4)
        self.dropout = kwargs.get('dropout', 0.1)
        self.max_length = kwargs.get('max_length', 100)
        self.num_epochs = kwargs.get('num_epochs', 100)
        self.learning_rate = kwargs.get('learning_rate', 0.001)
        self.batch_size = kwargs.get('batch_size', 2)
        self.pad_token = kwargs.get('pad_token', '<pad>')
        self.sos_token = kwargs.get('sos_token', '<sos>')
        self.eos_token = kwargs.get('eos_token', '<eos>')
        self.pad_idx = kwargs.get('pad_idx', 0)
        self.sos_idx = kwargs.get('sos_idx', 1)
        self.eos_idx = kwargs.get('eos_idx', 2)

class VocabularyManager:
    """Class to manage vocabulary creation and token mapping"""
    def __init__(self, config):
        self.config = config
        self.src_vocab = {}
        self.tgt_vocab = {}
        self.idx_to_src = {}
        self.idx_to_tgt = {}

    def set_predefined_vocab(self, src_vocab, tgt_vocab):
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.idx_to_src = {v: k for k, v in src_vocab.items()}
        self.idx_to_tgt = {v: k for k, v in tgt_vocab.items()}

    def tokenize(self, sentence, vocab):
        tokens = sentence.split()
        return [vocab.get(token, vocab.get(self.config.pad_token)) for token in tokens]

    def detokenize(self, indices, idx_to_token):
        return ' '.join([idx_to_token.get(idx, '<unk>') for idx in indices])

    def prepare_batch(self, src_sentences, tgt_sentences=None):
        src_batch = []
        for sent in src_sentences:
            tokens = self.tokenize(sent, self.src_vocab) + [self.src_vocab[self.config.eos_token]]
            while len(tokens) < 5:
                tokens.append(self.src_vocab[self.config.pad_token])
            src_batch.append(tokens)

        tgt_batch = None
        if tgt_sentences:
            tgt_batch = []
            for sent in tgt_sentences:
                tokens = [self.tgt_vocab[self.config.sos_token]] + self.tokenize(sent, self.tgt_vocab) + [self.tgt_vocab[self.config.eos_token]]
                tgt_batch.append(tokens)

        return torch.tensor(src_batch), torch.tensor(tgt_batch) if tgt_batch else None

class TransformerModel(nn.Module):
    def __init__(self, config):
        super(TransformerModel, self).__init__()
        self.src_embedding = nn.Embedding(config.src_vocab_size, config.embed_size)
        self.tgt_embedding = nn.Embedding(config.tgt_vocab_size, config.embed_size)
        self.positional_encoding = PositionalEncoding(config.embed_size, max_len=config.max_length)
        self.transformer = nn.Transformer(
            d_model=config.embed_size, 
            nhead=config.num_heads, 
            num_encoder_layers=config.num_layers, 
            num_decoder_layers=config.num_layers, 
            dim_feedforward=config.forward_expansion * config.embed_size, 
            dropout=config.dropout,
            batch_first=True
        )
        self.fc_out = nn.Linear(config.embed_size, config.tgt_vocab_size)

    def forward(self, src, tgt, src_mask=None, tgt_mask=None):
        src_embedded = self.positional_encoding(self.src_embedding(src))
        tgt_embedded = self.positional_encoding(self.tgt_embedding(tgt))
        transformer_output = self.transformer(
            src_embedded, tgt_embedded, src_key_padding_mask=src_mask, tgt_key_padding_mask=tgt_mask
        )
        out = self.fc_out(transformer_output)
        return out

class TransformerTrainer:
    """Class to handle training the transformer model"""
    def __init__(self, model, config):
        self.model = model
        self.config = config
        self.criterion = nn.CrossEntropyLoss(ignore_index=config.pad_idx)
        self.optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)

    def train_epoch(self, src, tgt):
        self.model.train()
        self.optimizer.zero_grad()
        output = self.model(src, tgt[:, :-1])
        output = output.reshape(-1, output.shape[2])
        tgt_output = tgt[:, 1:].reshape(-1)
        loss = self.criterion(output, tgt_output)
        loss.backward()
        self.optimizer.step()
        return loss.item()

    def evaluate(self, src, tgt, vocab_manager):
        with torch.no_grad():
            self.model.eval()
            eval_output = self.model(src, tgt[:, :-1])
            _, predicted = torch.max(eval_output, dim=2)
            return predicted

    def train(self, src, tgt, vocab_manager):
        print("\nTraining the model to translate English to Russian:")
        for epoch in range(self.config.num_epochs):
            loss = self.train_epoch(src, tgt)
            predicted = self.evaluate(src, tgt, vocab_manager)
            if epoch == self.config.num_epochs - 1 or epoch % 3 == 0:
                print(f"\nEpoch [{epoch + 1}/{self.config.num_epochs}], Loss: {loss:.4f}")
                print(f"Source: I love books")
                pred_sentence = [vocab_manager.idx_to_tgt[idx.item()] for idx in predicted[0]]
                print(f"Predicted translation: {' '.join(pred_sentence)}")
                target_sentence = [vocab_manager.idx_to_tgt[idx.item()] for idx in tgt[0, 1:]]
                print(f"Target translation: {' '.join(target_sentence)}")

class TranslationService:
    """Class to handle translation services"""
    def __init__(self, model, vocab_manager, config):
        self.model = model
        self.vocab_manager = vocab_manager
        self.config = config

    def translate_sentence(self, sentence, max_length=None):
        if max_length is None:
            max_length = self.config.max_length
        self.model.eval()
        if isinstance(sentence, str):
            tokens = sentence.split()
            src_indices = [self.vocab_manager.src_vocab.get(token, self.vocab_manager.src_vocab[self.config.pad_token]) for token in tokens]
            src_indices.append(self.vocab_manager.src_vocab[self.config.eos_token])
            while len(src_indices) < 5:
                src_indices.append(self.vocab_manager.src_vocab[self.config.pad_token])
        else:
            src_indices = sentence
        src_tensor = torch.tensor([src_indices])
        tgt_tensor = torch.tensor([[self.vocab_manager.tgt_vocab[self.config.sos_token]]])
        for _ in range(max_length - 1):
            with torch.no_grad():
                output = self.model(src_tensor, tgt_tensor)
            pred_token = output[0, -1].argmax().item()
            new_tgt = torch.zeros(1, tgt_tensor.size(1) + 1, dtype=torch.long)
            new_tgt[0, :-1] = tgt_tensor
            new_tgt[0, -1] = pred_token
            tgt_tensor = new_tgt
            if pred_token == self.vocab_manager.tgt_vocab[self.config.eos_token]:
                break
        predicted_indices = tgt_tensor[0].tolist()
        translated_tokens = []
        for idx in predicted_indices[1:]:
            if idx == self.vocab_manager.tgt_vocab[self.config.eos_token]:
                break
            translated_tokens.append(self.vocab_manager.idx_to_tgt.get(idx, '<unk>'))
        return translated_tokens

def main():
    config_params = {
        'src_vocab_size': 50,
        'tgt_vocab_size': 50,
        'embed_size': 32,
        'num_heads': 4,
        'num_layers': 3,
        'forward_expansion': 4,
        'dropout': 0.1,
        'max_length': 100,
        'num_epochs': 1000,
        'learning_rate': 0.001,
        'batch_size': 2,
        'pad_token': '<pad>',
        'sos_token': '<sos>',
        'eos_token': '<eos>',
        'pad_idx': 0,
        'sos_idx': 1,
        'eos_idx': 2,
    }
    config = TransformerConfig(**config_params)
    vocab_manager = VocabularyManager(config)
    eng_vocab = {
        config.pad_token: config.pad_idx, 
        config.sos_token: config.sos_idx, 
        config.eos_token: config.eos_idx, 
        'I': 3, 'you': 4, 'love': 5, 'like': 6, 'books': 7, 'music': 8, 'movies': 9, 'food': 10,
        'we': 11, 'they': 12, 'he': 13, 'she': 14, 'it': 15,
        'read': 16, 'watch': 17, 'eat': 18, 'play': 19, 'write': 20,
        'good': 21, 'bad': 22, 'beautiful': 23, 'interesting': 24, 'boring': 25,
        'coffee': 26, 'tea': 27, 'water': 28, 'cake': 29, 'bread': 30,
        'computer': 31, 'phone': 32, 'car': 33, 'house': 34, 'school': 35,
        'friend': 36, 'family': 37, 'mother': 38, 'father': 39, 'sister': 40,
        'brother': 41, 'dog': 42, 'cat': 43, 'bird': 44, 'fish': 45,
        'and': 46, 'or': 47, 'but': 48, 'because': 49
    }
    ru_vocab = {
        config.pad_token: config.pad_idx, 
        config.sos_token: config.sos_idx, 
        config.eos_token: config.eos_idx, 
        'я': 3, 'ты': 4, 'люблю': 5, 'нравится': 6, 'книги': 7, 'музыка': 8, 'фильмы': 9, 'еда': 10,
        'мы': 11, 'они': 12, 'он': 13, 'она': 14, 'оно': 15,
        'читать': 16, 'смотреть': 17, 'есть': 18, 'играть': 19, 'писать': 20,
        'хороший': 21, 'плохой': 22, 'красивый': 23, 'интересный': 24, 'скучный': 25,
        'кофе': 26, 'чай': 27, 'вода': 28, 'торт': 29, 'хлеб': 30,
        'компьютер': 31, 'телефон': 32, 'машина': 33, 'дом': 34, 'школа': 35,
        'друг': 36, 'семья': 37, 'мать': 38, 'отец': 39, 'сестра': 40,
        'брат': 41, 'собака': 42, 'кошка': 43, 'птица': 44, 'рыба': 45,
        'и': 46, 'или': 47, 'но': 48, 'потому': 49
    }
    vocab_manager.set_predefined_vocab(eng_vocab, ru_vocab)
    src = torch.tensor([
        [eng_vocab['I'], eng_vocab['love'], eng_vocab['books'], eng_vocab[config.eos_token], eng_vocab[config.pad_token]],
        [eng_vocab['you'], eng_vocab['like'], eng_vocab['music'], eng_vocab[config.eos_token], eng_vocab[config.pad_token]]
    ])
    print("Source sentences:")
    for i in range(src.shape[0]):
        print([vocab_manager.idx_to_src[idx.item()] for idx in src[i]])
    tgt = torch.tensor([
        [ru_vocab[config.sos_token], ru_vocab['я'], ru_vocab['люблю'], ru_vocab['книги'], ru_vocab[config.eos_token]],
        [ru_vocab[config.sos_token], ru_vocab['ты'], ru_vocab['нравится'], ru_vocab['музыка'], ru_vocab[config.eos_token]]
    ])
    print("Target sentences:")
    for i in range(tgt.shape[0]):
        print([vocab_manager.idx_to_tgt[idx.item()] for idx in tgt[i]])
    transformer = TransformerModel(config)
    output = transformer(src, tgt)
    print(f"Transformer Model Output Shape: {output.shape}")
    _, predicted = torch.max(output, dim=2)
    print("Predicted sequences:")
    for i in range(predicted.shape[0]):
        print([vocab_manager.idx_to_tgt.get(idx.item(), '<unknown>') for idx in predicted[i]])
    trainer = TransformerTrainer(transformer, config)
    trainer.train(src, tgt, vocab_manager)
    translation_service = TranslationService(transformer, vocab_manager, config)
    print("\nTesting the model with new sentences:")
    test_sentences = [
        "I love music",
        "you like books", 
        "I like movies"
    ]
    for test_sent in test_sentences:
        translated_tokens = translation_service.translate_sentence(test_sent)
        print(f"Test Session")
        print(f"Source: {test_sent}")
        print(f"Translation: {' '.join(translated_tokens)}")
        print()

if __name__ == "__main__":
    main()
# Out:
# Source sentences:
# ['I', 'love', 'books', '<eos>', '<pad>']
# ['you', 'like', 'music', '<eos>', '<pad>']
# Target sentences:
# ['<sos>', 'я', 'люблю', 'книги', '<eos>']
# ['<sos>', 'ты', 'нравится', 'музыка', '<eos>']
# Transformer Model Output Shape: torch.Size([2, 5, 50])
# Predicted sequences:
# ['оно', 'оно', 'она', 'она', 'брат']
# ['оно', 'друг', 'оно', 'друг', 'она']
#
# Training the model to translate English to Russian:
#
# Epoch [1/1000], Loss: 4.4071
# Source: I love books
# Predicted translation: оно оно оно <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [4/1000], Loss: 3.4910
# Source: I love books
# Predicted translation: <eos> <eos> <eos> <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [7/1000], Loss: 3.2598
# Source: I love books
# Predicted translation: <eos> <eos> <eos> <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [10/1000], Loss: 3.0644
# Source: I love books
# Predicted translation: <eos> <eos> <eos> <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [13/1000], Loss: 2.8599
# Source: I love books
# Predicted translation: <eos> <eos> <eos> <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [16/1000], Loss: 2.8018
# Source: I love books
# Predicted translation: книги <eos> книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [19/1000], Loss: 2.5617
# Source: I love books
# Predicted translation: книги книги книги книги
# Target translation: я люблю книги <eos>
#
# Epoch [22/1000], Loss: 2.3297
# Source: I love books
# Predicted translation: книги книги книги книги
# Target translation: я люблю книги <eos>
#
# Epoch [25/1000], Loss: 2.2120
# Source: I love books
# Predicted translation: книги книги книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [28/1000], Loss: 1.9419
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [31/1000], Loss: 1.9648
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [34/1000], Loss: 1.7094
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [37/1000], Loss: 1.5181
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [40/1000], Loss: 1.3955
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [43/1000], Loss: 1.2958
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [46/1000], Loss: 1.1844
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [49/1000], Loss: 0.9737
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [52/1000], Loss: 0.9205
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [55/1000], Loss: 0.8718
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [58/1000], Loss: 0.7727
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [61/1000], Loss: 0.6864
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [64/1000], Loss: 0.6122
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [67/1000], Loss: 0.5855
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [70/1000], Loss: 0.5314
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [73/1000], Loss: 0.4783
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [76/1000], Loss: 0.4442
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [79/1000], Loss: 0.3882
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [82/1000], Loss: 0.3634
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [85/1000], Loss: 0.3453
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [88/1000], Loss: 0.3318
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [91/1000], Loss: 0.2895
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [94/1000], Loss: 0.2851
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [97/1000], Loss: 0.2766
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [100/1000], Loss: 0.2429
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [103/1000], Loss: 0.2367
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [106/1000], Loss: 0.2058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [109/1000], Loss: 0.2129
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [112/1000], Loss: 0.1928
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [115/1000], Loss: 0.1889
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [118/1000], Loss: 0.1717
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [121/1000], Loss: 0.1780
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [124/1000], Loss: 0.1691
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [127/1000], Loss: 0.1514
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [130/1000], Loss: 0.1403
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [133/1000], Loss: 0.1357
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [136/1000], Loss: 0.1473
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [139/1000], Loss: 0.1235
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [142/1000], Loss: 0.1200
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [145/1000], Loss: 0.1324
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [148/1000], Loss: 0.1145
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [151/1000], Loss: 0.1047
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [154/1000], Loss: 0.0954
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [157/1000], Loss: 0.1054
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [160/1000], Loss: 0.1026
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [163/1000], Loss: 0.1058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [166/1000], Loss: 0.0934
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [169/1000], Loss: 0.0925
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [172/1000], Loss: 0.0875
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [175/1000], Loss: 0.0742
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [178/1000], Loss: 0.0786
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [181/1000], Loss: 0.0840
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [184/1000], Loss: 0.0798
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [187/1000], Loss: 0.0667
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [190/1000], Loss: 0.0711
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [193/1000], Loss: 0.0667
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [196/1000], Loss: 0.0680
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [199/1000], Loss: 0.0631
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [202/1000], Loss: 0.0587
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [205/1000], Loss: 0.0654
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [208/1000], Loss: 0.0537
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [211/1000], Loss: 0.0585
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [214/1000], Loss: 0.0533
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [217/1000], Loss: 0.0554
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [220/1000], Loss: 0.0474
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [223/1000], Loss: 0.0480
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [226/1000], Loss: 0.0502
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [229/1000], Loss: 0.0474
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [232/1000], Loss: 0.0491
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [235/1000], Loss: 0.0492
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [238/1000], Loss: 0.0424
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [241/1000], Loss: 0.0417
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [244/1000], Loss: 0.0475
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [247/1000], Loss: 0.0431
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [250/1000], Loss: 0.0376
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [253/1000], Loss: 0.0407
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [256/1000], Loss: 0.0426
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [259/1000], Loss: 0.0373
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [262/1000], Loss: 0.0399
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [265/1000], Loss: 0.0350
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [268/1000], Loss: 0.0372
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [271/1000], Loss: 0.0416
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [274/1000], Loss: 0.0348
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [277/1000], Loss: 0.0337
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [280/1000], Loss: 0.0308
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [283/1000], Loss: 0.0311
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [286/1000], Loss: 0.0308
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [289/1000], Loss: 0.0334
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [292/1000], Loss: 0.0334
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [295/1000], Loss: 0.0310
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [298/1000], Loss: 0.0309
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [301/1000], Loss: 0.0288
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [304/1000], Loss: 0.0285
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [307/1000], Loss: 0.0289
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [310/1000], Loss: 0.0276
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [313/1000], Loss: 0.0278
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [316/1000], Loss: 0.0266
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [319/1000], Loss: 0.0290
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [322/1000], Loss: 0.0251
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [325/1000], Loss: 0.0249
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [328/1000], Loss: 0.0242
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [331/1000], Loss: 0.0246
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [334/1000], Loss: 0.0262
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [337/1000], Loss: 0.0220
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [340/1000], Loss: 0.0236
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [343/1000], Loss: 0.0236
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [346/1000], Loss: 0.0217
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [349/1000], Loss: 0.0216
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [352/1000], Loss: 0.0227
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [355/1000], Loss: 0.0199
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [358/1000], Loss: 0.0228
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [361/1000], Loss: 0.0206
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [364/1000], Loss: 0.0202
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [367/1000], Loss: 0.0197
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [370/1000], Loss: 0.0182
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [373/1000], Loss: 0.0184
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [376/1000], Loss: 0.0173
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [379/1000], Loss: 0.0188
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [382/1000], Loss: 0.0180
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [385/1000], Loss: 0.0187
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [388/1000], Loss: 0.0181
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [391/1000], Loss: 0.0184
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [394/1000], Loss: 0.0162
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [397/1000], Loss: 0.0171
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [400/1000], Loss: 0.0177
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [403/1000], Loss: 0.0178
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [406/1000], Loss: 0.0180
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [409/1000], Loss: 0.0170
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [412/1000], Loss: 0.0166
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [415/1000], Loss: 0.0167
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [418/1000], Loss: 0.0156
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [421/1000], Loss: 0.0165
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [424/1000], Loss: 0.0143
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [427/1000], Loss: 0.0138
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [430/1000], Loss: 0.0150
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [433/1000], Loss: 0.0147
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [436/1000], Loss: 0.0171
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [439/1000], Loss: 0.0147
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [442/1000], Loss: 0.0156
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [445/1000], Loss: 0.0132
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [448/1000], Loss: 0.0150
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [451/1000], Loss: 0.0135
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [454/1000], Loss: 0.0152
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [457/1000], Loss: 0.0143
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [460/1000], Loss: 0.0134
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [463/1000], Loss: 0.0128
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [466/1000], Loss: 0.0139
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [469/1000], Loss: 0.0124
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [472/1000], Loss: 0.0127
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [475/1000], Loss: 0.0121
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [478/1000], Loss: 0.0116
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [481/1000], Loss: 0.0130
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [484/1000], Loss: 0.0118
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [487/1000], Loss: 0.0138
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [490/1000], Loss: 0.0113
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [493/1000], Loss: 0.0120
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [496/1000], Loss: 0.0117
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [499/1000], Loss: 0.0115
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [502/1000], Loss: 0.0099
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [505/1000], Loss: 0.0113
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [508/1000], Loss: 0.0119
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [511/1000], Loss: 0.0111
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [514/1000], Loss: 0.0105
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [517/1000], Loss: 0.0124
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [520/1000], Loss: 0.0115
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [523/1000], Loss: 0.0103
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [526/1000], Loss: 0.0145
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [529/1000], Loss: 0.0099
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [532/1000], Loss: 0.0105
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [535/1000], Loss: 0.0097
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [538/1000], Loss: 0.0094
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [541/1000], Loss: 0.0101
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [544/1000], Loss: 0.0104
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [547/1000], Loss: 0.0114
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [550/1000], Loss: 0.0105
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [553/1000], Loss: 0.0090
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [556/1000], Loss: 0.0103
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [559/1000], Loss: 0.0089
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [562/1000], Loss: 0.0094
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [565/1000], Loss: 0.0096
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [568/1000], Loss: 0.0089
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [571/1000], Loss: 0.0084
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [574/1000], Loss: 0.0095
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [577/1000], Loss: 0.0081
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [580/1000], Loss: 0.0097
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [583/1000], Loss: 0.0090
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [586/1000], Loss: 0.0080
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [589/1000], Loss: 0.0092
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [592/1000], Loss: 0.0081
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [595/1000], Loss: 0.0085
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [598/1000], Loss: 0.0084
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [601/1000], Loss: 0.0085
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [604/1000], Loss: 0.0083
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [607/1000], Loss: 0.0084
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [610/1000], Loss: 0.0074
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [613/1000], Loss: 0.0076
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [616/1000], Loss: 0.0080
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [619/1000], Loss: 0.0069
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [622/1000], Loss: 0.0077
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [625/1000], Loss: 0.0081
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [628/1000], Loss: 0.0076
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [631/1000], Loss: 0.0077
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [634/1000], Loss: 0.0079
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [637/1000], Loss: 0.0070
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [640/1000], Loss: 0.0072
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [643/1000], Loss: 0.0075
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [646/1000], Loss: 0.0079
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [649/1000], Loss: 0.0072
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [652/1000], Loss: 0.0072
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [655/1000], Loss: 0.0075
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [658/1000], Loss: 0.0069
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [661/1000], Loss: 0.0071
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [664/1000], Loss: 0.0067
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [667/1000], Loss: 0.0068
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [670/1000], Loss: 0.0068
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [673/1000], Loss: 0.0059
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [676/1000], Loss: 0.0065
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [679/1000], Loss: 0.0059
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [682/1000], Loss: 0.0059
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [685/1000], Loss: 0.0061
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [688/1000], Loss: 0.0062
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [691/1000], Loss: 0.0070
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [694/1000], Loss: 0.0073
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [697/1000], Loss: 0.0062
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [700/1000], Loss: 0.0059
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [703/1000], Loss: 0.0058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [706/1000], Loss: 0.0057
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [709/1000], Loss: 0.0060
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [712/1000], Loss: 0.0054
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [715/1000], Loss: 0.0058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [718/1000], Loss: 0.0063
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [721/1000], Loss: 0.0058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [724/1000], Loss: 0.0058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [727/1000], Loss: 0.0055
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [730/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [733/1000], Loss: 0.0050
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [736/1000], Loss: 0.0060
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [739/1000], Loss: 0.0061
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [742/1000], Loss: 0.0051
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [745/1000], Loss: 0.0055
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [748/1000], Loss: 0.0050
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [751/1000], Loss: 0.0057
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [754/1000], Loss: 0.0055
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [757/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [760/1000], Loss: 0.0049
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [763/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [766/1000], Loss: 0.0054
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [769/1000], Loss: 0.0049
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [772/1000], Loss: 0.0058
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [775/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [778/1000], Loss: 0.0054
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [781/1000], Loss: 0.0057
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [784/1000], Loss: 0.0051
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [787/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [790/1000], Loss: 0.0060
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [793/1000], Loss: 0.0047
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [796/1000], Loss: 0.0051
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [799/1000], Loss: 0.0049
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [802/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [805/1000], Loss: 0.0046
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [808/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [811/1000], Loss: 0.0046
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [814/1000], Loss: 0.0053
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [817/1000], Loss: 0.0048
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [820/1000], Loss: 0.0048
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [823/1000], Loss: 0.0051
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [826/1000], Loss: 0.0052
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [829/1000], Loss: 0.0045
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [832/1000], Loss: 0.0042
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [835/1000], Loss: 0.0046
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [838/1000], Loss: 0.0039
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [841/1000], Loss: 0.0050
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [844/1000], Loss: 0.0043
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [847/1000], Loss: 0.0042
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [850/1000], Loss: 0.0042
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [853/1000], Loss: 0.0047
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [856/1000], Loss: 0.0041
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [859/1000], Loss: 0.0042
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [862/1000], Loss: 0.0045
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [865/1000], Loss: 0.0047
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [868/1000], Loss: 0.0041
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [871/1000], Loss: 0.0046
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [874/1000], Loss: 0.0042
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [877/1000], Loss: 0.0043
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [880/1000], Loss: 0.0047
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [883/1000], Loss: 0.0043
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [886/1000], Loss: 0.0038
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [889/1000], Loss: 0.0053
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [892/1000], Loss: 0.0041
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [895/1000], Loss: 0.0039
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [898/1000], Loss: 0.0039
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [901/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [904/1000], Loss: 0.0037
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [907/1000], Loss: 0.0038
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [910/1000], Loss: 0.0038
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [913/1000], Loss: 0.0039
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [916/1000], Loss: 0.0034
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [919/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [922/1000], Loss: 0.0038
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [925/1000], Loss: 0.0038
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [928/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [931/1000], Loss: 0.0040
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [934/1000], Loss: 0.0045
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [937/1000], Loss: 0.0036
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [940/1000], Loss: 0.0034
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [943/1000], Loss: 0.0037
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [946/1000], Loss: 0.0034
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [949/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [952/1000], Loss: 0.0031
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [955/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [958/1000], Loss: 0.0041
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [961/1000], Loss: 0.0032
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [964/1000], Loss: 0.0031
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [967/1000], Loss: 0.0030
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [970/1000], Loss: 0.0038
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [973/1000], Loss: 0.0030
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [976/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [979/1000], Loss: 0.0033
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [982/1000], Loss: 0.0040
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [985/1000], Loss: 0.0035
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [988/1000], Loss: 0.0029
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [991/1000], Loss: 0.0034
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [994/1000], Loss: 0.0032
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [997/1000], Loss: 0.0030
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Epoch [1000/1000], Loss: 0.0031
# Source: I love books
# Predicted translation: я люблю книги <eos>
# Target translation: я люблю книги <eos>
#
# Testing the model with new sentences:
# Test Session
# Source: I love music
# Translation: ты нравится музыка
#
# Test Session
# Source: you like books
# Translation: ты нравится музыка
#
# Test Session
# Source: I like movies
# Translation: ты нравится музыка
