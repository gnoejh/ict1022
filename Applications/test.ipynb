# %% [markdown]
# ```mermaid
# graph TD
#     A[Candlestick Pattern Pairs]
#
#     subgraph S [Single Candle Patterns]
#       B[Hammer<br/>/ Hanging Man]
#       C[Inverted Hammer<br/>/ Shooting Star]
#       D[Doji<br/>/ Gravestone Doji]
#       E[Spinning Top<br/>/ Dragonfly Doji]
#       I[Bullish Marubozu<br/>/ Bearish Marubozu]
#     end
#
#     subgraph M [Multiple Candle Patterns]
#       F[Bullish Engulfing<br/>/ Bearish Engulfing]
#       G[Morning Star<br/>/ Evening Star]
#       H[Three White Soldiers<br/>/ Three Black Crows]
#       J[Piercing Line<br/>/ Dark Cloud Cover]
#       K[Rising Three Methods<br/>/ Falling Three Methods]
#     end
#
#     A --> S
#     A --> M
# ```

# %% [markdown]
# <svg width="800" height="150" xmlns="http://www.w3.org/1500/svg" style="background:black">
#   <!-- Candlestick 1: Bullish Hammer -->
#   <g transform="translate(50, 30)">
#     <!-- Wick -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <!-- Body (small, near top) -->
#     <rect x="5" y="10" width="15" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Label -->
#     <text x="0" y="80" font-size="12" fill="white">Bullish Hammer</text>
#   </g>
#
#   <!-- Candlestick 2: Bearish Hanging Man -->
#   <g transform="translate(150, 30)">
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="5" y="10" width="15" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Hanging Man</text>
#   </g>
#
#   <!-- Candlestick 3: Inverted Hammer -->
#   <g transform="translate(250, 30)">
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <!-- Body (small, near bottom) -->
#     <rect x="5" y="35" width="15" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Inverted Hammer</text>
#   </g>
#
#   <!-- Candlestick 4: Shooting Star -->
#   <g transform="translate(350, 30)">
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="5" y="35" width="15" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Shooting Star</text>
#   </g>
#
#   <!-- Candlestick 5: Doji -->
#   <g transform="translate(450, 30)">
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <!-- Doji body as a thin line -->
#     <line x1="5" y1="35" x2="25" y2="35" stroke="white" stroke-width="2"/>
#     <text x="0" y="80" font-size="12" fill="white">Doji</text>
#   </g>
#
#   <!-- Candlestick 6: Marubozu -->
#   <g transform="translate(550, 30)">
#     <!-- Full body, no wicks -->
#     <rect x="5" y="0" width="15" height="60" fill="green" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Marubozu</text>
#   </g>
# </svg>

# %% [markdown]
# <svg width="1150" height="600" xmlns="http://www.w3.org/1500/svg" style="background:black">
#   <!-- ------------------- Row 1: Single Candle Patterns ------------------- -->
#   <!-- Group 1: Hammer / Hanging Man -->
#   <g transform="translate(15,15)">
#     <!-- Left: Bullish Hammer (small body near top) -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="5" y="10" width="15" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Bearish Hanging Man (small body near top) -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="45" y="10" width="15" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Label -->
#     <text x="0" y="80" font-size="12" fill="white">Hammer / Hanging Man</text>
#   </g>
#
#   <!-- Group 2: Inverted Hammer / Shooting Star -->
#   <g transform="translate(240,15)">
#     <!-- Left: Inverted Hammer (body near bottom) -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="5" y="35" width="15" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Shooting Star (body near bottom) -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="45" y="35" width="15" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Inverted Hammer / Shooting Star</text>
#   </g>
#
#   <!-- Group 3: Doji / Gravestone Doji -->
#   <g transform="translate(460,15)">
#     <!-- Left: Doji (thin horizontal line) -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <line x1="5" y1="35" x2="25" y2="35" stroke="white" stroke-width="2"/>
#     <!-- Right: Gravestone Doji -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <line x1="45" y1="35" x2="65" y2="35" stroke="white" stroke-width="2"/>
#     <text x="0" y="80" font-size="12" fill="white">Doji / Gravestone Doji</text>
#   </g>
#
#   <!-- Group 4: Spinning Top / Dragonfly Doji -->
#   <g transform="translate(680,15)">
#     <!-- Left: Spinning Top (moderate body) -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="5" y="25" width="15" height="10" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Dragonfly Doji (similar structure) -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="45" y="25" width="15" height="10" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Spinning Top / Dragonfly Doji</text>
#   </g>
#
#   <!-- Group 5: Bullish Marubozu / Bearish Marubozu -->
#   <g transform="translate(900,15)">
#     <!-- Left: Bullish Marubozu (full body, no wick) -->
#     <rect x="5" y="0" width="15" height="60" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Bearish Marubozu (full body, no wick) -->
#     <rect x="45" y="0" width="15" height="60" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Marubozu</text>
#   </g>
#
#   <!-- ------------------- Row 2: Multiple Candle Patterns ------------------- -->
#   <!-- Set the vertical offset for the second row -->
#   <!-- Group 6: Bullish Engulfing / Bearish Engulfing -->
#   <g transform="translate(15,150)">
#     <!-- Bullish Engulfing: Left sequence (red small candle, then larger green candle) -->
#     <rect x="5" y="15" width="15" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="25" y="10" width="25" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Bearish Engulfing: Right sequence (green small candle, then larger red candle) -->
#     <rect x="65" y="10" width="25" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="95" y="15" width="15" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Bullish Engulfing / Bearish Engulfing</text>
#   </g>
#
#   <!-- Group 7: Morning Star / Evening Star -->
#   <g transform="translate(240,150)">
#     <!-- Morning Star: three candles: red, small (gray), then green -->
#     <rect x="5" y="15" width="15" height="30" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="25" y="25" width="10" height="10" fill="gray" stroke="white" stroke-width="1"/>
#     <rect x="40" y="10" width="15" height="35" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Evening Star: three candles: green, small (gray), then red -->
#     <rect x="70" y="10" width="15" height="35" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="95" y="25" width="10" height="10" fill="gray" stroke="white" stroke-width="1"/>
#     <rect x="110" y="15" width="15" height="30" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Morning Star / Evening Star</text>
#   </g>
#
#   <!-- Group 8: Three White Soldiers / Three Black Crows -->
#   <g transform="translate(460,150)">
#     <!-- Three White Soldiers (bullish): three ascending green candles -->
#     <rect x="5" y="10" width="15" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="25" y="5" width="15" height="45" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="45" y="0" width="15" height="50" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Three Black Crows (bearish): three descending red candles -->
#     <rect x="65" y="0" width="15" height="50" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="85" y="5" width="15" height="45" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="105" y="10" width="15" height="40" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Three White Soldiers / Three Black Crows</text>
#   </g>
#
#   <!-- Group 9: Piercing Line / Dark Cloud Cover -->
#   <g transform="translate(680,150)">
#     <!-- Piercing Line: red candle then overlapping green candle -->
#     <rect x="5" y="15" width="15" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="25" y="10" width="25" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Dark Cloud Cover: green candle then overlapping red candle -->
#     <rect x="65" y="10" width="25" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="95" y="15" width="15" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Piercing Line / Dark Cloud Cover</text>
#   </g>
#
#   <!-- Group 10: Rising Three Methods / Falling Three Methods -->
#   <g transform="translate(900,150)">
#     <!-- Rising Three Methods: long green candle, three small red candles, then long green candle -->
#     <rect x="5" y="0" width="15" height="50" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="25" y="15" width="10" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="40" y="17" width="10" height="18" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="55" y="15" width="10" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="70" y="0" width="15" height="50" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Falling Three Methods: long red candle, three small green candles, then long red candle -->
#     <rect x="100" y="0" width="15" height="50" fill="red" stroke="white" stroke-width="1"/>
#     <rect x="115" y="15" width="10" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="135" y="17" width="10" height="18" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="150" y="15" width="10" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <rect x="165" y="0" width="15" height="50" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Rising Three Methods / Falling Three Methods</text>
#   </g>
# </svg>

# %% [markdown]
# <svg width="1300" height="700" xmlns="http://www.w3.org/2000/svg" style="background:black">
#   <!-- ------------------- Row 1: Single Candle Patterns ------------------- -->
#   <!-- Group 1: Hammer / Hanging Man -->
#   <g transform="translate(20,20)">
#     <!-- Left: Bullish Hammer -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <!-- Centered on wick at x=15; new x = 15 - (13/2)=8.5 -->
#     <rect x="8.5" y="10" width="13" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Bearish Hanging Man, wick at x=55; new x = 55 - 6.5 = 48.5 -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="48.5" y="10" width="13" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Label -->
#     <text x="0" y="80" font-size="12" fill="white">Hammer / Hanging Man</text>
#   </g>
#
#   <!-- Group 2: Inverted Hammer / Shooting Star -->
#   <g transform="translate(240,20)">
#     <!-- Left: Inverted Hammer -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="8.5" y="35" width="13" height="15" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Shooting Star -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="48.5" y="35" width="13" height="15" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Inverted Hammer / Shooting Star</text>
#   </g>
#
#   <!-- Group 3: Doji / Gravestone Doji -->
#   <g transform="translate(460,20)">
#     <!-- Left: Doji; draw a thin horizontal line centered at x=15 -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <line x1="8.5" y1="35" x2="21.5" y2="35" stroke="white" stroke-width="2"/>
#     <!-- Right: Gravestone Doji -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <line x1="48.5" y1="35" x2="61.5" y2="35" stroke="white" stroke-width="2"/>
#     <text x="0" y="80" font-size="12" fill="white">Doji / Gravestone Doji</text>
#   </g>
#
#   <!-- Group 4: Spinning Top / Dragonfly Doji -->
#   <g transform="translate(680,20)">
#     <!-- Left: Spinning Top -->
#     <line x1="15" y1="0" x2="15" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="8.5" y="25" width="13" height="10" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Dragonfly Doji -->
#     <line x1="55" y1="0" x2="55" y2="60" stroke="white" stroke-width="2"/>
#     <rect x="48.5" y="25" width="13" height="10" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Spinning Top / Dragonfly Doji</text>
#   </g>
#
#   <!-- Group 5: Marubozu -->
#   <g transform="translate(900,20)">
#     <!-- Left: Bullish Marubozu; centered at x=15 -->
#     <rect x="8.5" y="0" width="13" height="60" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Right: Bearish Marubozu; centered at x=55 -->
#     <rect x="48.5" y="0" width="13" height="60" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Marubozu</text>
#   </g>
#
#   <!-- ------------------- Row 2: Multiple Candle Patterns ------------------- -->
#   <!-- Group 6: Bullish Engulfing / Bearish Engulfing -->
#   <g transform="translate(20,150)">
#     <!-- Bullish Engulfing: Left sequence -->
#     <!-- First candle: originally centered at 15 -->
#     <rect x="8.5" y="20" width="13" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Second candle: originally centered at 40 (x=30 + 10) -->
#     <rect x="33.5" y="10" width="13" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Bearish Engulfing: Right sequence -->
#     <!-- First candle: centered at 75 -->
#     <rect x="68.5" y="10" width="13" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 100 -->
#     <rect x="93.5" y="20" width="13" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Bullish Engulfing / Bearish Engulfing</text>
#   </g>
#
#   <!-- Group 7: Morning Star / Evening Star -->
#   <g transform="translate(240,150)">
#     <!-- Morning Star: three candles -->
#     <!-- First candle: centered at 15 -->
#     <rect x="8.5" y="15" width="13" height="30" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 40 -->
#     <rect x="33.5" y="25" width="13" height="10" fill="gray" stroke="white" stroke-width="1"/>
#     <!-- Third candle: centered at 65 -->
#     <rect x="58.5" y="10" width="13" height="35" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Evening Star: three candles -->
#     <!-- First candle: centered at 95 -->
#     <rect x="88.5" y="10" width="13" height="35" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 120 -->
#     <rect x="113.5" y="25" width="13" height="10" fill="gray" stroke="white" stroke-width="1"/>
#     <!-- Third candle: centered at 145 -->
#     <rect x="138.5" y="15" width="13" height="30" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Morning Star / Evening Star</text>
#   </g>
#
#   <!-- Group 8: Three White Soldiers / Three Black Crows -->
#   <g transform="translate(460,150)">
#     <!-- Three White Soldiers (bullish) -->
#     <!-- First candle: centered at 15 -->
#     <rect x="8.5" y="10" width="13" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 40 -->
#     <rect x="33.5" y="5" width="13" height="45" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Third candle: centered at 65 -->
#     <rect x="58.5" y="0" width="13" height="50" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Three Black Crows (bearish) -->
#     <!-- First candle: centered at 95 -->
#     <rect x="88.5" y="0" width="13" height="50" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 120 -->
#     <rect x="113.5" y="5" width="13" height="45" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Third candle: centered at 145 -->
#     <rect x="138.5" y="10" width="13" height="40" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Three White Soldiers / Three Black Crows</text>
#   </g>
#
#   <!-- Group 9: Piercing Line / Dark Cloud Cover -->
#   <g transform="translate(680,150)">
#     <!-- Piercing Line: left sequence -->
#     <!-- First candle: centered at 15 -->
#     <rect x="8.5" y="20" width="13" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 40 -->
#     <rect x="33.5" y="10" width="13" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Dark Cloud Cover: right sequence -->
#     <!-- First candle: centered at 75 -->
#     <rect x="68.5" y="10" width="13" height="40" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 100 -->
#     <rect x="93.5" y="20" width="13" height="25" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Piercing Line / Dark Cloud Cover</text>
#   </g>
#
#   <!-- Group 10: Rising Three Methods / Falling Three Methods -->
#   <g transform="translate(900,150)">
#     <!-- Rising Three Methods: left sequence -->
#     <!-- First candle: centered at 15 -->
#     <rect x="8.5" y="0" width="13" height="50" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 40 -->
#     <rect x="33.5" y="15" width="13" height="20" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Third candle: centered at 65 -->
#     <rect x="58.5" y="15" width="13" height="20" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Fourth candle: centered at 90 -->
#     <rect x="83.5" y="15" width="13" height="20" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Fifth candle: centered at 115 -->
#     <rect x="108.5" y="0" width="13" height="50" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Falling Three Methods: right sequence -->
#     <!-- First candle: centered at 145 -->
#     <rect x="138.5" y="0" width="13" height="50" fill="red" stroke="white" stroke-width="1"/>
#     <!-- Second candle: centered at 170 -->
#     <rect x="163.5" y="15" width="13" height="20" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Third candle: centered at 195 -->
#     <rect x="188.5" y="15" width="13" height="20" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Fourth candle: centered at 220 -->
#     <rect x="213.5" y="15" width="13" height="20" fill="green" stroke="white" stroke-width="1"/>
#     <!-- Fifth candle: centered at 245 -->
#     <rect x="238.5" y="0" width="13" height="50" fill="red" stroke="white" stroke-width="1"/>
#     <text x="0" y="80" font-size="12" fill="white">Rising Three Methods / Falling Three Methods</text>
#   </g>
# </svg>
